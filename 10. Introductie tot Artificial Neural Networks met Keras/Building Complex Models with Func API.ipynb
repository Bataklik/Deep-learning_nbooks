# %% [markdown]
# # 8. Building Complex Models with the Functional API
#
# ## 8.1. Introductie tot de Functional API
#
# Waar het `Sequential` model een simpele stapel lagen is, kun je met de **Functional API** complexere architecturen bouwen die niet-sequentieel zijn. Een bekend voorbeeld is het **Wide & Deep** netwerk (Cheng et al., 2016).
#
# ## 8.2. Het Wide & Deep Netwerk (Basis)
#
# In dit model wordt de input direct verbonden met de output (het **Wide** gedeelte) én via een reeks verborgen lagen (het **Deep** gedeelte).
#
# ### Constructie via symbolische verbindingen
#
# In de Functional API roep je lagen aan als functies om verbindingen te leggen. Er wordt op dit punt nog geen echte data verwerkt.

# %%
import keras
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split

# 1. Laad de juiste data (numerieke tabeldata in plaats van afbeeldingen)
housing = fetch_california_housing()

# 2. Splitsen
X_train_full, X_test, y_train_full, y_test = train_test_split(
    housing.data, housing.target, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(
    X_train_full, y_train_full, random_state=42)

# %% [markdown]
# 1. Lagen definiëren
#
#     Eerst definiëren we de "bouwstenen" van het netwerk. Door ze hier als variabelen op te slaan, kunnen we ze later specifiek aanroepen (bijvoorbeeld om de `normalization_layer` te trainen op de data statistieken).

# %%
normalization_layer = keras.layers.Normalization()
hidden_layer1 = keras.layers.Dense(30, activation="relu")
hidden_layer2 = keras.layers.Dense(30, activation="relu")
concat_layer = keras.layers.Concatenate()
output_layer = keras.layers.Dense(1)

# %% [markdown]
# 2. Verbindingen leggen (symbolisch)
#
#     Hier "bedraden" we het netwerk. Elke laag wordt aangeroepen met de vorige laag (of een lijst van lagen) als argument. Merk op dat de concat_layer zowel de directe input als de diepe output ontvangt, wat het een Wide & Deep architectuur maakt.

# %%
input_ = keras.layers.Input(shape=X_train.shape[1:]) # Input vorm specificeren
normalized = normalization_layer(input_)
hidden1 = hidden_layer1(normalized)
hidden2 = hidden_layer2(hidden1)
concat = concat_layer([normalized, hidden2]) # Concatenate voegt inputs samen
output = output_layer(concat)

# %% [markdown]
# 3. Het Model object creëren
#
#     Ten slotte bundelen we alles in een Model object. Omdat alle lagen symbolisch aan elkaar gelinkt zijn, hoef je Keras alleen te vertellen waar de stroom begint (inputs) en waar deze eindigt (outputs).

# %%
model = keras.Model(inputs=[input_], outputs=[output])
model.summary()
# Out:
# Model: "functional_13"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5       │ (None, 8)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization_20    │ (None, 8)         │         17 │ input_layer_5[0]… │
# │ (Normalization)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_32 (Dense)    │ (None, 30)        │        270 │ normalization_20… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_33 (Dense)    │ (None, 30)        │        930 │ dense_32[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_13      │ (None, 38)        │          0 │ normalization_20… │
# │ (Concatenate)       │                   │            │ dense_33[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_34 (Dense)    │ (None, 1)         │         39 │ concatenate_13[0… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,256 (4.91 KB)
#  Trainable params: 1,239 (4.84 KB)
#  Non-trainable params: 17 (72.00 B)

# %% [markdown]
# ## 3. Multiple Inputs & Multiple Outputs
#
# Soms wil je verschillende subsets van features naar verschillende paden sturen, of heb je meerdere outputs nodig (bijv. voor classificatie én lokalisatie).
#
# ### Architectuur opzet
#
# - **Wide pad:** Neemt bijvoorbeeld de eerste 5 features (0 t/m 4).
# - **Deep pad:** Neemt de laatste 6 features (2 t/m 7).
# - **Auxiliary Output:** Een extra output bovenop de verborgen lagen, vaak gebruikt voor **regularisatie**.
#
# ### Implementatie voorbeeld

# %%
input_wide = keras.layers.Input(shape=[5], name="wide_input")
input_deep = keras.layers.Input(shape=[6], name="deep_input")

norm_wide = keras.layers.Normalization()(input_wide)
norm_deep = keras.layers.Normalization()(input_deep)

hidden1 = keras.layers.Dense(30, activation="relu")(norm_deep)
hidden2 = keras.layers.Dense(30, activation="relu")(hidden1)

concat = keras.layers.concatenate([norm_wide, hidden2])
output = keras.layers.Dense(1, name="main_output")(concat)
aux_output = keras.layers.Dense(1, name="aux_output")(hidden2)

model = keras.Model(inputs=[input_wide, input_deep], outputs=[output, aux_output])

# %% [markdown]
# ## Multiple Inputs and Multiple Outputs
#
# In complexe scenario's volstaat een enkel pad niet. We bouwen hier een architectuur met **twee inputs** (Wide & Deep) en **twee outputs** (Main & Auxiliary).
#
# **Waarom meerdere inputs/outputs?**
#
# - **Meerdere taken:** Bijvoorbeeld tegelijkertijd een object classificeren én de locatie (bounding box) bepalen in een afbeelding.
# - **Regularisatie:** Een extra output (auxiliary) toevoegen aan een deel van het netwerk om te zorgen dat ook die lagen nuttige representaties leren.
# - **Verschillende databronnen:** Verschillende subsets van features naar verschillende delen van het model sturen.

# %% [markdown]
# **1. Model Architectuur opbouwen**
#
# In dit voorbeeld sturen we 5 features naar het 'Wide' pad en 6 features naar het 'Deep' pad (met overlap).

# %%
import keras

# Inputs definiëren
input_wide = keras.layers.Input(shape=[5], name="wide_input")  # Features 0 t/m 4
input_deep = keras.layers.Input(shape=[6], name="deep_input")  # Features 2 t/m 7

# Normalisatie lagen (apart opgeslagen voor .adapt())
norm_layer_wide = keras.layers.Normalization()
norm_layer_deep = keras.layers.Normalization()

norm_wide = norm_layer_wide(input_wide)
norm_deep = norm_layer_deep(input_deep)

# Deep pad: we maken en roepen Dense lagen in één regel aan voor beknoptheid
hidden1 = keras.layers.Dense(30, activation="relu")(norm_deep)
hidden2 = keras.layers.Dense(30, activation="relu")(hidden1)

# Paden samenvoegen
# Tip: keras.layers.concatenate (kleine letter) is een shortcut functie
concat = keras.layers.concatenate([norm_wide, hidden2])

# Outputs definiëren
output = keras.layers.Dense(1, name="main_output")(concat)
aux_output = keras.layers.Dense(1, name="aux_output")(hidden2)

# Het Model object
model = keras.Model(inputs=[input_wide, input_deep], outputs=[output, aux_output])

# %% [markdown]
# **2. Compileren met Loss Weights**
#
# Omdat we twee outputs hebben, moeten we twee losses opgeven. We geven de hoofdoutput meer gewicht ($0.9$) dan de hulpoutput ($0.1$).

# %%
# Data splitsen voor de twee paden
X_train_wide,X_train_deep=X_train[:,:5],X_train[:,2:]
X_valid_wide,X_valid_deep=X_valid[:,:5],X_valid[:,2:]
X_test_wide,X_test_deep=X_test[:,:5],X_test[:,2:]

# pretend new instances
X_new_wide,X_new_deep=X_test_wide[:3],X_test_deep[:3]


optimizer = keras.optimizers.Adam(learning_rate=1e-3)

model.compile(
    loss=("mse", "mse"),
    loss_weights=(0.9, 0.1),
    optimizer=optimizer,
   metrics={"main_output": ["RootMeanSquaredError"], "aux_output": ["RootMeanSquaredError"]}
)

# %% [markdown]
# **3. Data Splitsen en Training**
#
# We moeten de data handmatig splitsen zodat de juiste kolommen naar de juiste input-laag gaan.

# %%
# Normalisatie lagen trainen
norm_layer_wide.adapt(X_train_wide)
norm_layer_deep.adapt(X_train_deep)

# Trainen: geef inputs en targets door als tuples
history = model.fit(
    (X_train_wide, X_train_deep), (y_train, y_train),
    epochs=20,
    validation_data=((X_valid_wide, X_valid_deep), (y_valid, y_valid))
)
# Out:
# Epoch 1/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 735us/step - aux_output_RootMeanSquaredError: 1.4619 - aux_output_loss: 2.1367 - loss: 1.6332 - main_output_RootMeanSquaredError: 1.2559 - main_output_loss: 1.5770 - val_aux_output_RootMeanSquaredError: 2.4736 - val_aux_output_loss: 6.1157 - val_loss: 1.6771 - val_main_output_RootMeanSquaredError: 1.0880 - val_main_output_loss: 1.1832
# Epoch 2/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 423us/step - aux_output_RootMeanSquaredError: 0.8510 - aux_output_loss: 0.7241 - loss: 0.5706 - main_output_RootMeanSquaredError: 0.7440 - main_output_loss: 0.5535 - val_aux_output_RootMeanSquaredError: 1.7535 - val_aux_output_loss: 3.0733 - val_loss: 0.7529 - val_main_output_RootMeanSquaredError: 0.7035 - val_main_output_loss: 0.4948
# Epoch 3/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 426us/step - aux_output_RootMeanSquaredError: 0.7730 - aux_output_loss: 0.5977 - loss: 0.4856 - main_output_RootMeanSquaredError: 0.6879 - main_output_loss: 0.4735 - val_aux_output_RootMeanSquaredError: 0.8515 - val_aux_output_loss: 0.7248 - val_loss: 1.2476 - val_main_output_RootMeanSquaredError: 1.1426 - val_main_output_loss: 1.3051
# Epoch 4/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 423us/step - aux_output_RootMeanSquaredError: 0.7376 - aux_output_loss: 0.5438 - loss: 0.4359 - main_output_RootMeanSquaredError: 0.6511 - main_output_loss: 0.4238 - val_aux_output_RootMeanSquaredError: 0.8485 - val_aux_output_loss: 0.7197 - val_loss: 0.5061 - val_main_output_RootMeanSquaredError: 0.6945 - val_main_output_loss: 0.4822
# Epoch 5/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 440us/step - aux_output_RootMeanSquaredError: 0.7136 - aux_output_loss: 0.5092 - loss: 0.4021 - main_output_RootMeanSquaredError: 0.6246 - main_output_loss: 0.3902 - val_aux_output_RootMeanSquaredError: 0.8041 - val_aux_output_loss: 0.6464 - val_loss: 0.4157 - val_main_output_RootMeanSquaredError: 0.6246 - val_main_output_loss: 0.3900
# Epoch 6/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 430us/step - aux_output_RootMeanSquaredError: 0.6968 - aux_output_loss: 0.4856 - loss: 0.3835 - main_output_RootMeanSquaredError: 0.6101 - main_output_loss: 0.3722 - val_aux_output_RootMeanSquaredError: 0.6986 - val_aux_output_loss: 0.4879 - val_loss: 0.6413 - val_main_output_RootMeanSquaredError: 0.8114 - val_main_output_loss: 0.6581
# Epoch 7/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step - aux_output_RootMeanSquaredError: 0.6814 - aux_output_loss: 0.4643 - loss: 0.3701 - main_output_RootMeanSquaredError: 0.5997 - main_output_loss: 0.3595 - val_aux_output_RootMeanSquaredError: 0.6742 - val_aux_output_loss: 0.4545 - val_loss: 0.3872 - val_main_output_RootMeanSquaredError: 0.6162 - val_main_output_loss: 0.3797
# Epoch 8/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 423us/step - aux_output_RootMeanSquaredError: 0.6694 - aux_output_loss: 0.4480 - loss: 0.3638 - main_output_RootMeanSquaredError: 0.5953 - main_output_loss: 0.3543 - val_aux_output_RootMeanSquaredError: 1.0949 - val_aux_output_loss: 1.1984 - val_loss: 0.9820 - val_main_output_RootMeanSquaredError: 0.9787 - val_main_output_loss: 0.9575
# Epoch 9/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 432us/step - aux_output_RootMeanSquaredError: 0.6592 - aux_output_loss: 0.4345 - loss: 0.3576 - main_output_RootMeanSquaredError: 0.5908 - main_output_loss: 0.3490 - val_aux_output_RootMeanSquaredError: 0.7695 - val_aux_output_loss: 0.5919 - val_loss: 1.2222 - val_main_output_RootMeanSquaredError: 1.1368 - val_main_output_loss: 1.2916
# Epoch 10/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 454us/step - aux_output_RootMeanSquaredError: 0.6556 - aux_output_loss: 0.4298 - loss: 0.3698 - main_output_RootMeanSquaredError: 0.6026 - main_output_loss: 0.3630 - val_aux_output_RootMeanSquaredError: 1.6569 - val_aux_output_loss: 2.7440 - val_loss: 2.9016 - val_main_output_RootMeanSquaredError: 1.7085 - val_main_output_loss: 2.9176
# Epoch 11/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 428us/step - aux_output_RootMeanSquaredError: 0.6513 - aux_output_loss: 0.4241 - loss: 0.3572 - main_output_RootMeanSquaredError: 0.5914 - main_output_loss: 0.3498 - val_aux_output_RootMeanSquaredError: 1.3801 - val_aux_output_loss: 1.9039 - val_loss: 3.2791 - val_main_output_RootMeanSquaredError: 1.8525 - val_main_output_loss: 3.4301
# Epoch 12/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 428us/step - aux_output_RootMeanSquaredError: 0.6419 - aux_output_loss: 0.4122 - loss: 0.3517 - main_output_RootMeanSquaredError: 0.5874 - main_output_loss: 0.3452 - val_aux_output_RootMeanSquaredError: 2.3971 - val_aux_output_loss: 5.7431 - val_loss: 7.5974 - val_main_output_RootMeanSquaredError: 2.7934 - val_main_output_loss: 7.7991
# Epoch 13/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 424us/step - aux_output_RootMeanSquaredError: 0.6450 - aux_output_loss: 0.4162 - loss: 0.3649 - main_output_RootMeanSquaredError: 0.5994 - main_output_loss: 0.3593 - val_aux_output_RootMeanSquaredError: 2.3229 - val_aux_output_loss: 5.3930 - val_loss: 6.7874 - val_main_output_RootMeanSquaredError: 2.6348 - val_main_output_loss: 6.9386
# Epoch 14/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 444us/step - aux_output_RootMeanSquaredError: 0.6639 - aux_output_loss: 0.4407 - loss: 0.3837 - main_output_RootMeanSquaredError: 0.6143 - main_output_loss: 0.3773 - val_aux_output_RootMeanSquaredError: 0.9657 - val_aux_output_loss: 0.9323 - val_loss: 1.0308 - val_main_output_RootMeanSquaredError: 1.0206 - val_main_output_loss: 1.0412
# Epoch 15/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 443us/step - aux_output_RootMeanSquaredError: 0.6289 - aux_output_loss: 0.3955 - loss: 0.3401 - main_output_RootMeanSquaredError: 0.5779 - main_output_loss: 0.3341 - val_aux_output_RootMeanSquaredError: 0.6839 - val_aux_output_loss: 0.4676 - val_loss: 0.3944 - val_main_output_RootMeanSquaredError: 0.6215 - val_main_output_loss: 0.3862
# Epoch 16/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 431us/step - aux_output_RootMeanSquaredError: 0.6243 - aux_output_loss: 0.3897 - loss: 0.3333 - main_output_RootMeanSquaredError: 0.5719 - main_output_loss: 0.3271 - val_aux_output_RootMeanSquaredError: 0.6627 - val_aux_output_loss: 0.4391 - val_loss: 0.3980 - val_main_output_RootMeanSquaredError: 0.6272 - val_main_output_loss: 0.3933
# Epoch 17/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 455us/step - aux_output_RootMeanSquaredError: 0.6235 - aux_output_loss: 0.3888 - loss: 0.3304 - main_output_RootMeanSquaredError: 0.5691 - main_output_loss: 0.3239 - val_aux_output_RootMeanSquaredError: 0.6597 - val_aux_output_loss: 0.4352 - val_loss: 0.3593 - val_main_output_RootMeanSquaredError: 0.5923 - val_main_output_loss: 0.3508
# Epoch 18/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 471us/step - aux_output_RootMeanSquaredError: 0.6255 - aux_output_loss: 0.3914 - loss: 0.3327 - main_output_RootMeanSquaredError: 0.5712 - main_output_loss: 0.3265 - val_aux_output_RootMeanSquaredError: 0.6394 - val_aux_output_loss: 0.4088 - val_loss: 0.3620 - val_main_output_RootMeanSquaredError: 0.5973 - val_main_output_loss: 0.3567
# Epoch 19/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 452us/step - aux_output_RootMeanSquaredError: 0.6180 - aux_output_loss: 0.3819 - loss: 0.3298 - main_output_RootMeanSquaredError: 0.5692 - main_output_loss: 0.3240 - val_aux_output_RootMeanSquaredError: 0.6041 - val_aux_output_loss: 0.3649 - val_loss: 0.3079 - val_main_output_RootMeanSquaredError: 0.5491 - val_main_output_loss: 0.3015
# Epoch 20/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step - aux_output_RootMeanSquaredError: 0.6186 - aux_output_loss: 0.3826 - loss: 0.3264 - main_output_RootMeanSquaredError: 0.5658 - main_output_loss: 0.3200 - val_aux_output_RootMeanSquaredError: 0.6794 - val_aux_output_loss: 0.4615 - val_loss: 0.3909 - val_main_output_RootMeanSquaredError: 0.6189 - val_main_output_loss: 0.3829

# %% [markdown]
# **4. Evaluatie en Voorspelling**
#
# De resultaten van `evaluate` en `predict` worden nu teruggegeven als lijsten of tuples.
#
# Evaluatie

# %%
eval_results = model.evaluate((X_test_wide, X_test_deep), (y_test, y_test))
# Geeft: [weighted_sum_loss, main_loss, aux_loss, main_rmse, aux_rmse]
weighted_sum, main_loss, aux_loss, main_rmse, aux_rmse = eval_results
# Out:
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 314us/step - aux_output_RootMeanSquaredError: 0.6199 - aux_output_loss: 0.3843 - loss: 0.3265 - main_output_RootMeanSquaredError: 0.5658 - main_output_loss: 0.3196

# %% [markdown]
# Voorspellen

# %%
y_pred_tuple = model.predict((X_new_wide, X_new_deep))
y_pred_main, y_pred_aux = y_pred_tuple

# Omzetten naar een dictionary voor duidelijkheid:
y_pred_dict = dict(zip(model.output_names, y_pred_tuple))
y_pred_dict
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# {'main_output': array([[0.5522039],
#         [1.1439954],
#         [3.7478845]], dtype=float32),
#  'aux_output': array([[0.73428047],
#         [1.0183663 ],
#         [3.560885  ]], dtype=float32)}
